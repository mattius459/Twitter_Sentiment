# %%
# %%time
#Standard imports
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 10)

# %%
import pandas as pd
import re
from string import digits
import nltk
from fuzzywuzzy import fuzz

import time
start_time = time.time()
print("--- %s seconds ---" % (time.time() - start_time))

pd.set_option('display.max_rows', 550)
pd.set_option('display.max_columns', 40)
pd.set_option('display.max_colwidth', 200)
# Out:
# --- 0.0006489753723144531 seconds ---

# %%
#Combine Fragmented files into one single file


df1 = pd.read_csv('Big_Directory/GetOldTweets3-master-5/Feb_26.csv')
df2 = pd.read_csv('Big_Directory/GetOldTweets3-master-5/FEB_25.csv')
df3 = pd.read_csv('Big_Directory/GetOldTweets3-master-5/FEB_24.csv')
df4 = pd.read_csv('Big_Directory/GetOldTweets3-master-5/FEB_21.csv')
df5 = pd.read_csv('Big_Directory/GetOldTweets3-master-5/FEB_19.csv')
df6 = pd.read_csv('Big_Directory/GetOldTweets3-master-5/FEB_18.csv')
df7 = pd.read_csv('Big_Directory/GetOldTweets3-master-5/FEB_17.csv')
df8 = pd.read_csv('Big_Directory/GetOldTweets3-master-5/FEB_15.csv')
df9 = pd.read_csv('Big_Directory/GetOldTweets3-master-5/FEB_14.csv')
df10 = pd.read_csv('Big_Directory/GetOldTweets3-master-5/FEB_12.csv')
df11 = pd.read_csv('Big_Directory/GetOldTweets3-master-1/FEB_06_18.csv')
df12 = pd.read_csv('Big_Directory/GetOldTweets3-master-1/FEB_01_18.csv')

#df6 = pd.read_csv('Big_Directory/GetOldTweets3-master-1/JUN_01.csv')
#df7 = pd.read_csv('Big_Directory/GetOldTweets3-master-1/JUN_20.csv')

#df7 = pd.read_csv('Big_Directory/GetOldTweets3-master-2/JUL_19.csv')
#df8 = pd.read_csv('Big_Directory/GetOldTweets3-master-2/JUL_18.csv')
#df9 = pd.read_csv('Big_Directory/GetOldTweets3-master-2/JUL_11.csv')
#df10 = pd.read_csv('Big_Directory/GetOldTweets3-master-2/JUL_02.csv')
#df11 = pd.read_csv('Big_Directory/GetOldTweets3-master-2/JUL_01.csv')

#df7 = pd.read_csv('Big_Directory/GetOldTweets3-master-3/AUG_28.csv')
#df8 = pd.read_csv('Big_Directory/GetOldTweets3-master-3/AUG_26.csv')
#df9 = pd.read_csv('Big_Directory/GetOldTweets3-master-3/AUG_19.csv')
#df10 = pd.read_csv('Big_Directory/GetOldTweets3-master-3/AUG_16.csv')
#df11 = pd.read_csv('Big_Directory/GetOldTweets3-master-3/AUG_14.csv')
#df12 = pd.read_csv('Big_Directory/GetOldTweets3-master-3/AUG_08.csv')
#df13 = pd.read_csv('Big_Directory/GetOldTweets3-master-3/AUG_02.csv')
#df14 = pd.read_csv('Big_Directory/GetOldTweets3-master-3/AUG_01.csv')

#df7 = pd.read_csv('Big_Directory/GetOldTweets3-master-4/SEP_25.csv')
#df8 = pd.read_csv('Big_Directory/GetOldTweets3-master-4/SEP_24.csv')
#df9 = pd.read_csv('Big_Directory/GetOldTweets3-master-4/SEP_23.csv')
#df10 = pd.read_csv('Big_Directory/GetOldTweets3-master-4/SEP_20.csv')
#df11 = pd.read_csv('Big_Directory/GetOldTweets3-master-4/SEP_17.csv')
#df12 = pd.read_csv('Big_Directory/GetOldTweets3-master-4/SEP_16.csv')
#df13 = pd.read_csv('Big_Directory/GetOldTweets3-master-4/SEP_15.csv')
#df14 = pd.read_csv('Big_Directory/GetOldTweets3-master-4/SEP_14.csv')
#df15 = pd.read_csv('Big_Directory/GetOldTweets3-master-4/SEP_02.csv')
#df16 = pd.read_csv('Big_Directory/GetOldTweets3-master-4/SEP_01.csv')

#df7 = pd.read_csv('Big_Directory/GetOldTweets3-master-5/OCT_28.csv')
#df8 = pd.read_csv('Big_Directory/GetOldTweets3-master-5/OCT_23.csv')
#df9 = pd.read_csv('Big_Directory/GetOldTweets3-master-5/OCT_22.csv')
#df10 = pd.read_csv('Big_Directory/GetOldTweets3-master-5/OCT_17.csv')
#df11 = pd.read_csv('Big_Directory/GetOldTweets3-master-5/OCT_08.csv')
#df12 = pd.read_csv('Big_Directory/GetOldTweets3-master-5/OCT_07.csv')
#df13 = pd.read_csv('Big_Directory/GetOldTweets3-master-5/OCT_01.csv')

#df4 = pd.read_csv('Big_Directory/GetOldTweets3-master-1/NOV_01.csv')
#df5 = pd.read_csv('Big_Directory/GetOldTweets3-master-1/NOV_03.csv')
#df6 = pd.read_csv('Big_Directory/GetOldTweets3-master-1/NOV_10.csv')
#df7 = pd.read_csv('Big_Directory/GetOldTweets3-master-1/NOV_11.csv')
#df8 = pd.read_csv('Big_Directory/GetOldTweets3-master-1/NOV_14.csv')
#df9 = pd.read_csv('Big_Directory/GetOldTweets3-master-1/NOV_15.csv')
#df10 = pd.read_csv('Big_Directory/GetOldTweets3-master-1/NOV_20.csv')
#df11 = pd.read_csv('Big_Directory/GetOldTweets3-master-1/NOV_25.csv')
#df12 = pd.read_csv('Big_Directory/GetOldTweets3-master-1/NOV_26.csv')
#df13 = pd.read_csv('Big_Directory/GetOldTweets3-master-1/NOV_27.csv')

#df4 = pd.read_csv('Big_Directory/GetOldTweets3-master-2/DEC_26.csv')
#df5 = pd.read_csv('Big_Directory/GetOldTweets3-master-2/DEC_24.csv')
#df6 = pd.read_csv('Big_Directory/GetOldTweets3-master-2/DEC_22.csv')
#df7 = pd.read_csv('Big_Directory/GetOldTweets3-master-2/DEC_21.csv')
#df8 = pd.read_csv('Big_Directory/GetOldTweets3-master-2/DEC_14.csv')
#df9 = pd.read_csv('Big_Directory/GetOldTweets3-master-2/DEC_13.csv')
#df10 = pd.read_csv('Big_Directory/GetOldTweets3-master-3/DEC_11.csv')
#df11 = pd.read_csv('Big_Directory/GetOldTweets3-master-3/DEC_10.csv')
#df12 = pd.read_csv('Big_Directory/GetOldTweets3-master-3/DEC_08.csv')
#df13 = pd.read_csv('Big_Directory/GetOldTweets3-master-3/DEC_05.csv')
#df14 = pd.read_csv('Big_Directory/GetOldTweets3-master-3/DEC_03.csv')

#df4 = pd.read_csv('Big_Directory/GetOldTweets3-master-4/JAN_30.csv')
#df5 = pd.read_csv('Big_Directory/GetOldTweets3-master-4/JAN_26.csv')
#df6 = pd.read_csv('Big_Directory/GetOldTweets3-master-4/JAN_25.csv')
#df7 = pd.read_csv('Big_Directory/GetOldTweets3-master-4/JAN_24.csv')
#df8 = pd.read_csv('Big_Directory/GetOldTweets3-master-4/JAN_23.csv')
#df9 = pd.read_csv('Big_Directory/GetOldTweets3-master-4/JAN_21.csv')
#df10 = pd.read_csv('Big_Directory/GetOldTweets3-master-4/JAN_07.csv')

#df4 = pd.read_csv('Big_Directory/GetOldTweets3-master-5/FEB_26.csv')
#df5 = pd.read_csv('Big_Directory/GetOldTweets3-master-5/FEB_25.csv')
#df6 = pd.read_csv('Big_Directory/GetOldTweets3-master-5/FEB_24.csv')
#df7 = pd.read_csv('Big_Directory/GetOldTweets3-master-5/FEB_21.csv')
#df8 = pd.read_csv('Big_Directory/GetOldTweets3-master-5/FEB_19.csv')
#df9 = pd.read_csv('Big_Directory/GetOldTweets3-master-5/FEB_18.csv')
#df10 = pd.read_csv('Big_Directory/GetOldTweets3-master-5/FEB_17.csv')
#df11 = pd.read_csv('Big_Directory/GetOldTweets3-master-5/FEB_15.csv')
#df12 = pd.read_csv('Big_Directory/GetOldTweets3-master-5/FEB_14.csv')
#df13 = pd.read_csv('Big_Directory/GetOldTweets3-master-5/FEB_12.csv')
#df14 = pd.read_csv('Big_Directory/GetOldTweets3-master-1/FEB_06_18.csv')
#df15 = pd.read_csv('Big_Directory/GetOldTweets3-master-1/FEB_01_18.csv')

#df4 = pd.read_csv('Big_Directory/GetOldTweets3-master-4/JAN_30.csv')
#df5 = pd.read_csv('Big_Directory/GetOldTweets3-master-4/JAN_26.csv')
#df6 = pd.read_csv('Big_Directory/GetOldTweets3-master-4/JAN_25.csv')
#df7 = pd.read_csv('Big_Directory/GetOldTweets3-master-4/JAN_24.csv')
#df8 = pd.read_csv('Big_Directory/GetOldTweets3-master-4/JAN_23.csv')
#df9 = pd.read_csv('Big_Directory/GetOldTweets3-master-4/JAN_21.csv')
#df10 = pd.read_csv('Big_Directory/GetOldTweets3-master-4/JAN_18.csv')
#df11 = pd.read_csv('Big_Directory/GetOldTweets3-master-4/JAN_17.csv')
#df12 = pd.read_csv('Big_Directory/GetOldTweets3-master-4/JAN_07.csv')


#df = pd.read_csv('JUN17.csv')



df = df1.append([df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12], ignore_index=True)

#Remove dupes
print(len(df))
df = df.drop_duplicates()
print(len(df))

df.to_csv('FEB18.csv')

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# 866907
# 862704
# --- 30.13615608215332 seconds ---

# %%
df.head(50)
# Out:
#                    date         username  retweets  favorites  \
# 0   2018-02-28 23:59:59   CryptoNewbieee         0          1
# 2   2018-02-28 23:59:57     _HayleyElise         0          2
# 4   2018-02-28 23:59:47     Scot_Striker         0          1
# 5   2018-02-28 23:59:47     bitethfinder         0          0
# 6   2018-02-28 23:59:46         boroghor         0          0
# 10  2018-02-28 23:59:29    MadlynThorley         0          0
# 11  2018-02-28 23:59:26      billyhuicad         0          0
# 12  2018-02-28 23:59:24          _WillC_         0          0
# 13  2018-02-28 23:59:19   williammahan50         0          1
# 14  2018-02-28 23:59:16        PorterG94         0          1
# 19  2018-02-28 23:59:04  CyberToolsBooks         0          0
# 20  2018-02-28 23:59:03      CyberDomain         0          0
# 21  2018-02-28 23:59:01         BostInno         1          2
# 22  2018-02-28 23:59:01  CyberToolsBooks         0          0
# ...

# %%
"""

Preprocess:

Remove dupes
Remove http
Remove numbers
Remove all-too-freq tweets by user
Remove rows with less than X words
Remove adverts using fuzzy
Make lowercase
Remove stop words
Lemma
Stem

"""
# Out:
# '\n\nPreprocess:\n\nRemove dupes\nRemove http\nRemove numbers\nRemove all-too-freq tweets by user\nRemove rows with less than X words\nRemove adverts using fuzzy\nMake lowercase\nRemove stop words\nLemma\nStem\n\n'

# %%
#remove unnecessary columns
df = df.drop(columns = ['to', 'geo', 'mentions'])

# %%
#Remove dupes
print(len(df))
df = df.drop_duplicates()
print(len(df))
#702244
# Out:
# 862704
# 862704

# %%
#Remove http
df['text'] = df['text'].str.replace('http://.*', '', regex=True)
df['text'] = df['text'].str.replace('https://.*', '', regex=True)

# %%
#Remove numbers
df['text'] = df['text'].str.replace('\d+', '')

# %%
#Remove @usernames
df['text'] = df['text'].str.replace('@\w{3,}', '', regex=True)

# %%
#Remove symbols #, $ etc.

symbols_list = ['$', '#', '.', '\"', '-', ',', '/', '!', ':', ';', '?', '%', '&', '|', ')', '(', '+', '*']

for symbol in symbols_list:
    df['text'] = df['text'].str.replace(symbol, '')

# %%
#Remove tweets with less than X words
count = df['text'].str.count(' ').add(1).value_counts(sort=False)

df = df.drop(df[df['text'].str.count(' ').add(1) < 10].index)

# %%
#Make lowercase
df['text'] = df['text'].str.lower()

# %%
#Lemma?

# %%
df.tail(100)
# Out:
#                        date         username  retweets  favorites  \
# 866778  2018-02-01 00:02:10        duppy1151         0          0
# 866779  2018-02-01 00:02:07   crypto_effects         0          0
# 866780  2018-02-01 00:02:05  bitcoins_future         1          1
# 866781  2018-02-01 00:02:03    AliceWonder32         1          1
# 866782  2018-02-01 00:02:02   TechInvestClub         1          0
# 866784  2018-02-01 00:02:01         hann_925         0          0
# 866785  2018-02-01 00:02:00     lynderopabon         0          1
# 866786  2018-02-01 00:01:58     btctickerbot         0          0
# 866787  2018-02-01 00:01:56    RandyHilarski         6          9
# 866788  2018-02-01 00:01:54     grushtenniak         0          0
# 866789  2018-02-01 00:01:51     darkisdarkn1         0          0
# 866790  2018-02-01 00:01:47         RillaBiz         0          1
# 866792  2018-02-01 00:01:46   Crypto_Skipper         8         32
# ...

# %%
len(df)
# Out:
# 649978

# %%
"""
#Remove adverts using Fuzzy
fuzz_ratio = 0

username_set = set(df['username'])


unique_username_list = list(username_set)
print(len(unique_username_list))

for user in unique_username_list:
    single_user_df = df.loc[df['username'] == user]
    #pick two random tweets from a given user, apply fuzzy ratio, iterate 4 times and then average to find overall similarity between tweets.
    if len(single_user_df) > 29:
        for i in range(6):
            two_tweets = single_user_df.sample(n=2)
            #print(two_tweets['text'])
            fuzz_ratio += fuzz.ratio(two_tweets['text'].iloc[0], two_tweets['text'].iloc[1])
        fuzz_ratio = fuzz_ratio / 6
        print(fuzz_ratio, user)
        if fuzz_ratio > 50:
            df.drop(df[df['username'] == user].index)
print("--- %s seconds ---" % (time.time() - start_time))
"""
# Out:
# '\n#Remove adverts using Fuzzy\nfuzz_ratio = 0\n\nusername_set = set(df[\'username\'])\nunique_username_list = list(username_set)\nprint(len(unique_username_list))\n\nfor user in unique_username_list:\n    single_user_df = df.loc[df[\'username\'] == user]\n    #pick two random tweets from a given user, apply fuzzy ratio, iterate 4 times and then average to find overall similarity between tweets.\n    if len(single_user_df) > 29:\n        for i in range(6):\n            two_tweets = single_user_df.sample(n=2)\n            #print(two_tweets[\'text\'])\n            fuzz_ratio += fuzz.ratio(two_tweets[\'text\'].iloc[0], two_tweets[\'text\'].iloc[1])\n        fuzz_ratio = fuzz_ratio / 6\n        print(fuzz_ratio, user)\n        if fuzz_ratio > 50:\n            df.drop(df[df[\'username\'] == user].index)\nprint("--- %s seconds ---" % (time.time() - start_time))\n'

# %%
#str.split tokenizes, kind of?
df['text'] = df['text'].str.split()

# %%
#Remove stop words
from nltk.corpus import stopwords

extra_stop_words = ['usd', 'there\'s', 'bitcoin', 'btc']

stop_words = stopwords.words('english')
stop_words.extend(extra_stop_words)
df['text'] = df['text'].apply(lambda x: [item for item in x if item not in stop_words])

print(stop_words)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...
