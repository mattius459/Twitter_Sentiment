# %%
import pandas as pd

pd.set_option('display.max_rows', 550)
pd.set_option('display.max_columns', 40)
pd.set_option('display.max_colwidth', 200)

# %%
#Read username set for each month
unique_username_list = pd.read_csv('unique_username_list_JUN.csv', header=None)
df = unique_username_list.rename(columns = {0:'username'})
#user_movie_likes = user_movie_likes.rename(columns = {0: 'user_id', 1 : 'movie_id'})

# %%
#Join sets together to get final list

# %%
#Get all tweets for a given user and create a new document

#count tweets per user
df
# Out:
#               username
# 0              MCRSINV
# 1             Tap_Coin
# 2        johnmilanoski
# 3               r0ni43
# 4           Job_Nijsen
# 5        TheAliceSmith
# 6           MistyGjoni
# 7          SirFlorianJ
# 8           decentrust
# 9            Flibberdy
# 10      ryanjoshuayork
# 11           sweepatic
# 12       _CoryMvtthews
# 13            Farasalt
# 14       chris__martin
# 15       JayBitcoinBTC
# 16        azrealtorwil
# 17              Qzedia
# 18               Seeko
# 19             jerardg
# 20        AbdullahMoai
# 21            NeilKNet
# 22              Smegoy
# 23     AdamJor06684655
# 24        KevinDSamuel
# 25            OZarksMO
# 26         caracol0830
# 27      amagi_libertas
# 28      peacefulposter
# 29         McMcgregory
# 30        cryptoholics
# 31          Burrmarket
# 32      JourneysNonnie
# 33         DoctorRobin
# 34             IMastas
# 35     shahidzaheermeo
# 36         aimee_maree
# 37     MissusBojangles
# 38           coinsalad
# ...

# %%
#find  numtweets per user
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
#Combine all user-documents together for topic modeling
